# %% [markdown]
# # Pandas + Matplotlib 개념 노트
#
# 필요한 개념을 바로 찾을 수 있도록 **주제별로 쪼갠 노트북 모음**입니다.
#
# ## 추천 순서
# ### Pandas
# 1. `pandas/01_데이터프레임_기초.ipynb`
# 2. `pandas/02_선택_필터링.ipynb`
# 3. `pandas/03_정렬_groupby_집계.ipynb`
# 4. `pandas/04_결측치_이상치.ipynb`
#
# ### Matplotlib
# 5. `matplotlib/01_기초_선그래프.ipynb`
# 6. `matplotlib/02_막대_히스토그램.ipynb`
# 7. `matplotlib/03_산점도_subplot.ipynb`
#
# ### 전체 흐름
# 8. `99_분석흐름_치트시트.ipynb`
#
# ---
#
# ## 빠른 검색표
#
# | 찾고 싶은 것 | 파일 |
# |---|---|
# | `head`, `info`, `shape`, `columns` | Pandas 기초 |
# | `loc`, `iloc`, 불리언 필터 | 선택·필터링 |
# | `isin`, `between`, `~` | 선택·필터링 |
# | `sort_values` | 정렬·집계 |
# | `groupby`, `agg`, `size`, `count` | 정렬·집계 |
# | 평균, 분산, 표준편차 | 정렬·집계 |
# | 결측치, IQR, 3시그마 | 결측치·이상치 |
# | `plot`, `title`, `xlabel`, `ylabel` | Matplotlib 기초 |
# | `bar`, `barh` | 막대·히스토그램 |
# | `hist`, `bins` | 막대·히스토그램 |
# | `scatter`, `alpha` | 산점도 |
# | `axhline`, `axvline` | 산점도 |
# | `subplot`, `suptitle`, `tight_layout` | 산점도·subplot |
